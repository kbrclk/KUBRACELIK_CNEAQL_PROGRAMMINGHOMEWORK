# %%
token = "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"

# %%
# !git config --global user.email "mvcdllacl@gmail.com"
# !git config --global user.name "Kübra"

# %%
username = "kbrclk"
repo = "KUBRACELIK_CNEAQL_PROGRAMMINGHOMEWORK"
# !git clone https://{token}@github.com/{username}/{repo}
# Out:
# fatal: destination path 'KUBRACELIK_CNEAQL_PROGRAMMINGHOMEWORK' already exists and is not an empty directory.

# %%
# %pwd
# Out:
# '/content/KUBRACELIK_CNEAQL_PROGRAMMINGHOMEWORK'

# %%
# %cd /content/KUBRACELIK_CNEAQL_PROGRAMMINGHOMEWORK
# Out:
# /content/KUBRACELIK_CNEAQL_PROGRAMMINGHOMEWORK

# %%
# %pwd
# Out:
# '/content/KUBRACELIK_CNEAQL_PROGRAMMINGHOMEWORK'

# %%
# !touch myfirstfile.txt

# %%
# !git add myfirstfile.txt

# %%
# !git commit -m "I created the first file"
# Out:
# [main ec31e64] I created the first file
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 myfirstfile.txt

# %%
# !git push
# Out:
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 290 bytes | 290.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/kbrclk/KUBRACELIK_CNEAQL_PROGRAMMINGHOMEWORK
#    a97aa63..ec31e64  main -> main

# %%
# !git pull
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 977 bytes | 977.00 KiB/s, done.
# From https://github.com/kbrclk/KUBRACELIK_CNEAQL_PROGRAMMINGHOMEWORK
#    ec31e64..ef569e3  main       -> origin/main
# Updating ec31e64..ef569e3
# Fast-forward
#  myfirstfile.txt | 1 +
#  1 file changed, 1 insertion(+)

# %%
# !touch KUBRACELIK_CNEAQL_COLAB_GITHUB.ipynb

# %%
# !git add KUBRACELIK_CNEAQL_COLAB_GITHUB.ipynb

# %%
# !git commit -m "Colab GitHub connection"
# Out:
# [main 7113cda] Colab GitHub connection
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 KUBRACELIK_CNEAQL_COLAB_GITHUB.ipynb

# %%
# !git push
# Out:
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 379 bytes | 379.00 KiB/s, done.
# Total 3 (delta 0), reused 1 (delta 0), pack-reused 0
# To https://github.com/kbrclk/KUBRACELIK_CNEAQL_PROGRAMMINGHOMEWORK
#    f4f4067..7113cda  main -> main
